# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Housing.csv")
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
print(df.info())
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB
# None
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
print(df.columns)
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
#        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#        'parking', 'prefarea', 'furnishingstatus'],
#       dtype='object')

# %%
df['Area_per_Bedroom'] = df['area'] / df['bedrooms']

df['Total_Rooms'] = df['bedrooms'] + df['bathrooms']

df['Price_per_Area'] = df['price'] / df['area']

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus  \
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished
#
#    Area_per_Bedroom  Total_Rooms  Price_per_Area
# 0            1855.0            6     1792.452830
# 1            2240.0            8     1367.187500
# 2            3320.0            5     1229.919679
# 3            1875.0            6     1628.666667
# 4            1855.0            5     1537.735849

# %%
df.fillna(df.mean(numeric_only=True), inplace=True)

# %%
print(df.columns.tolist())
# Out:
# ['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'parking', 'Area_per_Bedroom', 'Total_Rooms', 'Price_per_Area', 'mainroad_no', 'mainroad_yes', 'guestroom_no', 'guestroom_yes', 'basement_no', 'basement_yes', 'hotwaterheating_no', 'hotwaterheating_yes', 'airconditioning_no', 'airconditioning_yes', 'prefarea_no', 'prefarea_yes', 'furnishingstatus_furnished', 'furnishingstatus_semi-furnished', 'furnishingstatus_unfurnished']

# %%
for col in df.columns:
  print(col)
# Out:
# price
# area
# bedrooms
# bathrooms
# stories
# parking
# Area_per_Bedroom
# Total_Rooms
# Price_per_Area
# mainroad_no
# mainroad_yes
# guestroom_no
# guestroom_yes
# basement_no
# basement_yes
# hotwaterheating_no
# hotwaterheating_yes
# airconditioning_no
# airconditioning_yes
# prefarea_no
# prefarea_yes
# furnishingstatus_furnished
# furnishingstatus_semi-furnished
# furnishingstatus_unfurnished

# %%
df=pd.get_dummies(df)

# %%
print(df.head())
# Out:
#       price  area  bedrooms  bathrooms  stories  parking  Area_per_Bedroom  \
# 0  13300000  7420         4          2        3        2            1855.0
# 1  12250000  8960         4          4        4        3            2240.0
# 2  12250000  9960         3          2        2        2            3320.0
# 3  12215000  7500         4          2        2        3            1875.0
# 4  11410000  7420         4          1        2        2            1855.0
#
#    Total_Rooms  Price_per_Area  mainroad_no  ...  basement_yes  \
# 0            6     1792.452830        False  ...         False
# 1            8     1367.187500        False  ...         False
# 2            5     1229.919679        False  ...          True
# 3            6     1628.666667        False  ...          True
# 4            5     1537.735849        False  ...          True
#
#    hotwaterheating_no  hotwaterheating_yes  airconditioning_no  \
# 0                True                False               False
# 1                True                False               False
# 2                True                False                True
# 3                True                False               False
# 4                True                False               False
#
#    airconditioning_yes  prefarea_no  prefarea_yes  furnishingstatus_furnished  \
# 0                 True        False          True                        True
# 1                 True         True         False                        True
# 2                False        False          True                       False
# 3                 True        False          True                        True
# 4                 True         True         False                        True
#
#    furnishingstatus_semi-furnished  furnishingstatus_unfurnished
# 0                            False                         False
# 1                            False                         False
# 2                             True                         False
# 3                            False                         False
# 4                            False                         False
#
# [5 rows x 24 columns]

# %%
import numpy as np

df['price_log'] = np.log1p(df['price'])
print(df[['price', 'price_log']].head())
# Out:
#       price  price_log
# 0  13300000  16.403275
# 1  12250000  16.321037
# 2  12250000  16.321037
# 3  12215000  16.318175
# 4  11410000  16.250001

# %%
import numpy as np

df['price_log'] = np.log1p(df['price'])

print(df[['price', 'price_log']].head())
# Out:
#       price  price_log
# 0  13300000  16.403275
# 1  12250000  16.321037
# 2  12250000  16.321037
# 3  12215000  16.318175
# 4  11410000  16.250001

# %%
df.to_csv('enhanced_housing_dataset.csv', index=False)

# %%
print(df.head())
print(df.shape)
# Out:
#       price  area  bedrooms  bathrooms  stories  parking  Area_per_Bedroom  \
# 0  13300000  7420         4          2        3        2            1855.0
# 1  12250000  8960         4          4        4        3            2240.0
# 2  12250000  9960         3          2        2        2            3320.0
# 3  12215000  7500         4          2        2        3            1875.0
# 4  11410000  7420         4          1        2        2            1855.0
#
#    Total_Rooms  Price_per_Area  mainroad_no  ...  hotwaterheating_no  \
# 0            6     1792.452830        False  ...                True
# 1            8     1367.187500        False  ...                True
# 2            5     1229.919679        False  ...                True
# 3            6     1628.666667        False  ...                True
# 4            5     1537.735849        False  ...                True
#
#    hotwaterheating_yes  airconditioning_no  airconditioning_yes  prefarea_no  \
# 0                False               False                 True        False
# 1                False               False                 True         True
# 2                False                True                False        False
# 3                False               False                 True        False
# 4                False               False                 True         True
#
#    prefarea_yes  furnishingstatus_furnished  furnishingstatus_semi-furnished  \
# 0          True                        True                            False
# 1         False                        True                            False
# 2          True                       False                             True
# 3          True                        True                            False
# 4         False                        True                            False
#
#    furnishingstatus_unfurnished  price_log
# 0                         False  16.403275
# 1                         False  16.321037
# 2                         False  16.321037
# 3                         False  16.318175
# 4                         False  16.250001
#
# [5 rows x 25 columns]
# (545, 25)

# %%
(df.head())
# Out:
#       price  area  bedrooms  bathrooms  stories  parking  Area_per_Bedroom  \
# 0  13300000  7420         4          2        3        2            1855.0
# 1  12250000  8960         4          4        4        3            2240.0
# 2  12250000  9960         3          2        2        2            3320.0
# 3  12215000  7500         4          2        2        3            1875.0
# 4  11410000  7420         4          1        2        2            1855.0
#
#    Total_Rooms  Price_per_Area  mainroad_no  ...  hotwaterheating_no  \
# 0            6     1792.452830        False  ...                True
# 1            8     1367.187500        False  ...                True
# 2            5     1229.919679        False  ...                True
# 3            6     1628.666667        False  ...                True
# 4            5     1537.735849        False  ...                True
#
#    hotwaterheating_yes  airconditioning_no  airconditioning_yes  prefarea_no  \
# 0                False               False                 True        False
# 1                False               False                 True         True
# 2                False                True                False        False
# 3                False               False                 True        False
# 4                False               False                 True         True
#
#    prefarea_yes  furnishingstatus_furnished  furnishingstatus_semi-furnished  \
# 0          True                        True                            False
# 1         False                        True                            False
# 2          True                       False                             True
# 3          True                        True                            False
# 4         False                        True                            False
#
#    furnishingstatus_unfurnished  price_log
# 0                         False  16.403275
# 1                         False  16.321037
# 2                         False  16.321037
# 3                         False  16.318175
# 4                         False  16.250001
#
# [5 rows x 25 columns]

# %%
(df.shape)
# Out:
# (545, 25)
